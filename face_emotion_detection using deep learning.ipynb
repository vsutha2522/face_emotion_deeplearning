# %%
#!pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\huawei\anaconda3\envs\dl\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\huawei\anaconda3\envs\dl\lib\site-packages (from opencv-python) (1.26.4)

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img=cv2.imread("happy1.jpg")

# %%
plt.imshow(img)

# %% [markdown]
# # change bgr to rgb color

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
#!pip install deepface

# %%
from deepface import DeepFace

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:16<00:00,  4.18s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 5.0001293199679595e-06,
#    'disgust': 5.798824006472129e-10,
#    'fear': 0.6605543589922404,
#    'happy': 99.33933015700163,
#    'sad': 0.00010591510948984489,
#    'surprise': 1.4908806190050902e-07,
#    'neutral': 8.754803626520524e-06},
#   'dominant_emotion': 'happy',
#   'region': {'x': 40,
#    'y': 41,
#    'w': 88,
#    'h': 88,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.92,
#   'age': 24,
#   'gender': {'Woman': 2.2353438660502434, 'Man': 97.764652967453},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.9479390090965634,
#    'indian': 0.09229432875927263,
#    'black': 0.010436974011097416,
#    'white': 83.81436370696805,
#    'middle eastern': 3.6683341812094556,
#    'latino hispanic': 11.466637192168069},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
predictions[0]
# Out:
# {'emotion': {'angry': 5.0001293199679595e-06,
#   'disgust': 5.798824006472129e-10,
#   'fear': 0.6605543589922404,
#   'happy': 99.33933015700163,
#   'sad': 0.00010591510948984489,
#   'surprise': 1.4908806190050902e-07,
#   'neutral': 8.754803626520524e-06},
#  'dominant_emotion': 'happy',
#  'region': {'x': 40,
#   'y': 41,
#   'w': 88,
#   'h': 88,
#   'left_eye': None,
#   'right_eye': None},
#  'face_confidence': 0.92,
#  'age': 24,
#  'gender': {'Woman': 2.2353438660502434, 'Man': 97.764652967453},
#  'dominant_gender': 'Man',
#  'race': {'asian': 0.9479390090965634,
#   'indian': 0.09229432875927263,
#   'black': 0.010436974011097416,
#   'white': 83.81436370696805,
#   'middle eastern': 3.6683341812094556,
#   'latino hispanic': 11.466637192168069},
#  'dominant_race': 'white'}

# %% [markdown]
# # Draw rectangle box across the face

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

gray=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,predictions['dominant_emotion'],(0,50),font,fontscale= 1,color=(0,0,255),thickness = 2);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 font=cv2.FONT_HERSHEY_SIMPLEX
# ----> 2 cv2.putText(img,predictions['dominant_emotion'],(0,50),font,fontscale= 1,color=(0,0,255),thickness = 2)
#
# TypeError: list indices must be integers or slices, not str
